# %%
import cv2
import os

# %%
# Directory containing the images
input_dir = "Results3"  # Folder containing input images
output_dir = "Outliers"  # Folder to save cropped images

# Create the output directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# Global variables to store cropping data
ref_point = []
rectangles = []  # Store all selected rectangles for an image
cropping = False

def crop_region(event, x, y, flags, param):
    """Mouse callback function to handle region selection."""
    global ref_point, cropping

    if event == cv2.EVENT_LBUTTONDOWN:  # Left mouse button pressed
        ref_point = [(x, y)]  # Start point
        cropping = True

    elif event == cv2.EVENT_LBUTTONUP:  # Left mouse button released
        ref_point.append((x, y))  # End point
        cropping = False

        # Add the rectangle to the list and draw it on the image
        rectangles.append(ref_point)
        cv2.rectangle(image_resized, ref_point[0], ref_point[1], (0, 255, 0), 2)
        cv2.imshow("Image", image_resized)

def resize_image(image, width=1200):
    """Resize image to make it larger while keeping the original aspect ratio."""
    h, w = image.shape[:2]
    scale_factor = width / w
    new_dimensions = (width, int(h * scale_factor))
    return cv2.resize(image, new_dimensions, interpolation=cv2.INTER_LINEAR)

# Load all images from the input directory
image_files = [f for f in os.listdir(input_dir) if f.endswith((".jpg", ".png", ".jpeg"))]

# Start cropping process
quit_all = False  # Flag to quit all loops
for idx, file_name in enumerate(image_files):
    if quit_all:  # Exit the outer loop if "Quit All" is triggered
        break

    # Read the image
    image_path = os.path.join(input_dir, file_name)
    original_image = cv2.imread(image_path)
    image_resized = resize_image(original_image)  # Resize the image for display
    clone = image_resized.copy()  # Clone to reset if needed
    rectangles = []  # Reset the rectangle list for each image

    cv2.namedWindow("Image")
    cv2.setMouseCallback("Image", crop_region)

    print(f"Processing: {file_name}")
    while True:
        cv2.imshow("Image", image_resized)
        key = cv2.waitKey(1) & 0xFF

        if key == 27:  # Press `Esc` to quit all loops
            quit_all = True
            break

        elif key == ord("r"):  # Reset the cropping and rectangles
            image_resized = clone.copy()
            rectangles = []
            print("Reset all selections.")

        elif key == ord("c"):  # Confirm cropping and save all selected regions
            if rectangles:
                scale_w = original_image.shape[1] / image_resized.shape[1]
                scale_h = original_image.shape[0] / image_resized.shape[0]

                for i, rect in enumerate(rectangles):
                    x1, y1 = int(rect[0][0] * scale_w), int(rect[0][1] * scale_h)
                    x2, y2 = int(rect[1][0] * scale_w), int(rect[1][1] * scale_h)

                    # Crop and save the region
                    cropped = original_image[y1:y2, x1:x2]
                    crop_name = os.path.join(output_dir, f"{file_name}_crop_{i}.png")
                    try:
                        cv2.imwrite(crop_name, cropped)
                        print(f"Saved: {crop_name}")
                    except Exception as e:
                        print(f"Error saving {crop_name}: {e}")
            else:
                print("No rectangles selected.")

        elif key == ord("q"):  # Quit current image
            break

    cv2.destroyWindow("Image")  # Close the window after processing the current image

cv2.destroyAllWindows()
# Out:
# Processing: 0001.jpg
# Processing: 0002.jpg
# Processing: 0003.jpg
# Processing: 0005.jpg
# Processing: 0006.jpg
# Processing: 0010.jpg
# Processing: 0011.jpg
# Processing: 0012.jpg
# Processing: 0013.jpg
# Processing: 0014.jpg
# Processing: 0015.jpg
# Processing: 0016.jpg
# Processing: 0019.jpg
# Processing: 0021.jpg
# Processing: 0022.jpg
# Processing: 0023.jpg
# Processing: 0024.jpg
# Processing: 0025.jpg
# Saved: Outliers\0025.jpg_crop_0.png
# Processing: 0026.jpg
# Saved: Outliers\0026.jpg_crop_0.png
# Processing: 0027.jpg
# Saved: Outliers\0027.jpg_crop_0.png
# Processing: 0028.jpg
# Saved: Outliers\0028.jpg_crop_0.png
# Processing: 0029.jpg
# Processing: 0030.jpg
# Processing: 0031.jpg
# Processing: 0032.jpg
# Processing: 0033.jpg
# Processing: 0034.jpg
# Processing: 0036.jpg
# Processing: 0037.jpg
# Processing: 0038.jpg
# Processing: 0039.jpg
# Processing: 0040.jpg
# Processing: 0041.jpg
# Processing: 0042.jpg
# Processing: 0043.jpg
# Processing: 0046.jpg
# Processing: 0047.jpg
# Saved: Outliers\0047.jpg_crop_0.png
# Saved: Outliers\0047.jpg_crop_0.png
# Saved: Outliers\0047.jpg_crop_1.png
# Error saving Outliers\0047.jpg_crop_2.png: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:798: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# Processing: 0048.jpg
# Saved: Outliers\0048.jpg_crop_0.png
# Processing: 0052.jpg
# Processing: 0053.jpg
# Processing: 0054.jpg
# Processing: 0055.jpg
# Processing: 0056.jpg
# Processing: 0057.jpg
# Processing: 0058.jpg
# Saved: Outliers\0058.jpg_crop_0.png
# Processing: 0059.jpg
# Saved: Outliers\0059.jpg_crop_0.png
# Saved: Outliers\0059.jpg_crop_1.png
# Error saving Outliers\0059.jpg_crop_2.png: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:798: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# Processing: 0060.jpg
# Saved: Outliers\0060.jpg_crop_0.png
# Processing: 0061.jpg
# Processing: 0062.jpg
# No rectangles selected.
# Processing: 0064.jpg
# Saved: Outliers\0064.jpg_crop_0.png
# Saved: Outliers\0064.jpg_crop_1.png
# Error saving Outliers\0064.jpg_crop_2.png: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:798: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# Processing: 0065.jpg
# Saved: Outliers\0065.jpg_crop_0.png
# Processing: 0066.jpg
# Processing: 0067.jpg
# Processing: 0068.jpg
# Saved: Outliers\0068.jpg_crop_0.png
# Processing: 0070.jpg
# Saved: Outliers\0070.jpg_crop_0.png
# Saved: Outliers\0070.jpg_crop_0.png
# Error saving Outliers\0070.jpg_crop_1.png: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:798: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# Saved: Outliers\0070.jpg_crop_2.png
# Processing: 0073.jpg
# No rectangles selected.
# Processing: 0074.jpg
# Processing: 0079.jpg
# Saved: Outliers\0079.jpg_crop_0.png
# Saved: Outliers\0079.jpg_crop_1.png
# Saved: Outliers\0079.jpg_crop_2.png
# Processing: 0082.jpg
# Saved: Outliers\0082.jpg_crop_0.png
# Processing: 0084.jpg
# No rectangles selected.
# Processing: 0085.jpg
# Saved: Outliers\0085.jpg_crop_0.png
# Processing: 0086.jpg
# Processing: 0087.jpg
# Saved: Outliers\0087.jpg_crop_0.png
# Saved: Outliers\0087.jpg_crop_1.png
# Error saving Outliers\0087.jpg_crop_2.png: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:798: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# Processing: 0088.jpg
# Saved: Outliers\0088.jpg_crop_0.png
# Saved: Outliers\0088.jpg_crop_1.png
# Error saving Outliers\0088.jpg_crop_2.png: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:798: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# Processing: 0089.jpg
# Processing: 0090.jpg
# Processing: 0091.jpg
# Processing: 0093.jpg
# Processing: 0094.jpg
# Reset all selections.
# Saved: Outliers\0094.jpg_crop_0.png
# Error saving Outliers\0094.jpg_crop_1.png: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:798: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# Processing: 0095.jpg
# Saved: Outliers\0095.jpg_crop_0.png
# Saved: Outliers\0095.jpg_crop_1.png
# Saved: Outliers\0095.jpg_crop_2.png
# Processing: 0097.jpg
# Saved: Outliers\0097.jpg_crop_0.png
# Processing: 0098.jpg
# Saved: Outliers\0098.jpg_crop_0.png
# Processing: 0099.jpg
# Processing: 0100.jpg
# Processing: 0101.jpg
# Saved: Outliers\0101.jpg_crop_0.png
# Saved: Outliers\0101.jpg_crop_1.png
# Saved: Outliers\0101.jpg_crop_2.png
# Processing: 0102.jpg
# Saved: Outliers\0102.jpg_crop_0.png
# Processing: 0103.jpg
# Processing: 0104.jpg
# Saved: Outliers\0104.jpg_crop_0.png
# Error saving Outliers\0104.jpg_crop_1.png: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:798: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# Processing: 0106.jpg
# Saved: Outliers\0106.jpg_crop_0.png
# Saved: Outliers\0106.jpg_crop_1.png
# Saved: Outliers\0106.jpg_crop_2.png
# Processing: 0107.jpg
# Processing: 0108.jpg
# Saved: Outliers\0108.jpg_crop_0.png
# Saved: Outliers\0108.jpg_crop_1.png
# Saved: Outliers\0108.jpg_crop_2.png
# Processing: 0109.jpg
# Error saving Outliers\0109.jpg_crop_0.png: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:798: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# Saved: Outliers\0109.jpg_crop_1.png
# Processing: 0110.jpg
# Saved: Outliers\0110.jpg_crop_0.png
# Processing: 0111.jpg
# Saved: Outliers\0111.jpg_crop_0.png
# Processing: 0112.jpg
# Saved: Outliers\0112.jpg_crop_0.png
# Saved: Outliers\0112.jpg_crop_1.png
# Saved: Outliers\0112.jpg_crop_2.png
# Processing: 0113.jpg
# Processing: 0119.jpg
# Saved: Outliers\0119.jpg_crop_0.png
# Saved: Outliers\0119.jpg_crop_1.png
# Processing: 0120.jpg
# Saved: Outliers\0120.jpg_crop_0.png
# Processing: 0121.jpg
# Saved: Outliers\0121.jpg_crop_0.png
# Processing: 0122.jpg
# Saved: Outliers\0122.jpg_crop_0.png
# Processing: 0123.jpg
# No rectangles selected.
# Processing: 0124.jpg
# Processing: 0126.jpg
# Processing: 0127.jpg
# Saved: Outliers\0127.jpg_crop_0.png
# Processing: 0131.jpg
# Saved: Outliers\0131.jpg_crop_0.png
# Processing: 0133.jpg
# Processing: 0136.jpg
# Saved: Outliers\0136.jpg_crop_0.png
# Processing: 0137.jpg
# No rectangles selected.
# Processing: 0138.jpg
# Processing: 0139.jpg
# Processing: 0141.jpg
# Processing: 0142.jpg
# Processing: 0144.jpg
# Processing: 0145.jpg
# Saved: Outliers\0145.jpg_crop_0.png
# Saved: Outliers\0145.jpg_crop_1.png
# Processing: 0146.jpg
# Processing: 0147.jpg
# Processing: 0151.jpg
# Processing: 0152.jpg
# Saved: Outliers\0152.jpg_crop_0.png
# Processing: 0153.jpg
# Processing: 0154.jpg
# Processing: 0155.jpg
# Saved: Outliers\0155.jpg_crop_0.png
# Error saving Outliers\0155.jpg_crop_1.png: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:798: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# Error saving Outliers\0155.jpg_crop_2.png: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:798: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# Saved: Outliers\0155.jpg_crop_3.png
# Processing: 0156.jpg
# Processing: 0157.jpg
# Error saving Outliers\0157.jpg_crop_0.png: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:798: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# Saved: Outliers\0157.jpg_crop_1.png
# Saved: Outliers\0157.jpg_crop_2.png
# Processing: 0158.jpg
# Saved: Outliers\0158.jpg_crop_0.png
# Processing: 0159.jpg
# Processing: 0160.jpg
# Processing: 0161.jpg
# Saved: Outliers\0161.jpg_crop_0.png
# Saved: Outliers\0161.jpg_crop_1.png
# Processing: 0162.jpg
# Saved: Outliers\0162.jpg_crop_0.png
# Processing: 0163.jpg
# Processing: 0164.jpg
# Processing: 0165.jpg
# Error saving Outliers\0165.jpg_crop_0.png: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:798: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# Saved: Outliers\0165.jpg_crop_1.png
# Saved: Outliers\0165.jpg_crop_2.png
# Processing: 0166.jpg
# Reset all selections.
# Saved: Outliers\0166.jpg_crop_0.png
# Processing: 0167.jpg
# Saved: Outliers\0167.jpg_crop_0.png
# Processing: 0168.jpg
# Processing: 0169.jpg
# Processing: 0170.jpg
# Processing: 0171.jpg
# Saved: Outliers\0171.jpg_crop_0.png
# Saved: Outliers\0171.jpg_crop_1.png
# Processing: 0172.jpg
# Processing: 0173.jpg
# Processing: 0174.jpg
# Processing: 0175.jpg
# Reset all selections.
# Error saving Outliers\0175.jpg_crop_0.png: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:798: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# Saved: Outliers\0175.jpg_crop_1.png
# Processing: 0176.jpg
# Processing: 0177.jpg
# Processing: 0178.jpg
# Processing: 0179.jpg
# Processing: 0180.jpg
# Processing: 0181.jpg
# Saved: Outliers\0181.jpg_crop_0.png
# Processing: 0182.jpg
# Saved: Outliers\0182.jpg_crop_0.png
# Saved: Outliers\0182.jpg_crop_1.png
# Processing: 0183.jpg
# Saved: Outliers\0183.jpg_crop_0.png
# Processing: 0184.jpg
# Processing: 0185.jpg
# Processing: 0186.jpg
# Processing: 0187.jpg
# Saved: Outliers\0187.jpg_crop_0.png
# Saved: Outliers\0187.jpg_crop_1.png
# Processing: 0188.jpg
# Processing: 0189.jpg
# Processing: 0190.jpg
# Processing: 0191.jpg
# Saved: Outliers\0191.jpg_crop_0.png
# Saved: Outliers\0191.jpg_crop_1.png
# Processing: 0192.jpg
# Processing: 0193.jpg
# Processing: 0194.jpg
# Processing: 0195.jpg
# Processing: 0196.jpg
# Processing: 0197.jpg
# Processing: 0198.jpg
# Saved: Outliers\0198.jpg_crop_0.png
# Saved: Outliers\0198.jpg_crop_1.png
# Error saving Outliers\0198.jpg_crop_2.png: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:798: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# Processing: 0199.jpg
# Processing: 0200.jpg
# Processing: 0201.jpg
# Processing: 0202.jpg
# Processing: 0203.jpg
# Processing: 0204.jpg
# Saved: Outliers\0204.jpg_crop_0.png
# Saved: Outliers\0204.jpg_crop_1.png
# Processing: 0205.jpg
# Processing: 0206.jpg
# Processing: 0207.jpg
# Processing: 0208.jpg
# Processing: 0209.jpg
# Processing: 0210.jpg
# Processing: 0211.jpg
# Processing: 0212.jpg
# Processing: 0213.jpg
# Processing: 0214.jpg
# Saved: Outliers\0214.jpg_crop_0.png
# Processing: 0215.jpg
# Processing: 0216.jpg
# Processing: 0217.jpg
# Processing: 0218.jpg
# Processing: 0219.jpg
# Processing: 0220.jpg
# Processing: 0221.jpg
# Processing: 0222.jpg
# Processing: 0223.jpg
# Processing: 0224.jpg
# Processing: 0225.jpg
# Processing: 0226.jpg
# Processing: 0227.jpg
# Processing: 0228.jpg
# Processing: 0229.jpg
# Processing: 0230.jpg
# Processing: 0231.jpg
# Processing: 0232.jpg
# Processing: 0233.jpg
# Processing: 0234.jpg
# Processing: 0235.jpg
# Processing: 0236.jpg
# Processing: 0237.jpg
# Processing: 0238.jpg
# Processing: 0239.jpg
# Processing: 0240.jpg
# Processing: 0241.jpg
# Reset all selections.
# Processing: 0242.jpg
# Processing: 0243.jpg
# Processing: 0244.jpg
# Processing: 0245.jpg
# Error saving Outliers\0245.jpg_crop_0.png: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:798: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# Processing: 0246.jpg
# Processing: 0247.jpg
# Processing: 0248.jpg
# Processing: 0249.jpg
# Processing: 0250.jpg
# Processing: 0251.jpg
# Saved: Outliers\0251.jpg_crop_0.png
# Processing: 0252.jpg
# Error saving Outliers\0252.jpg_crop_0.png: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:798: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# Saved: Outliers\0252.jpg_crop_1.png
# Processing: 0253.jpg
